# %% [markdown]
# <a href="https://colab.research.google.com/github/AniketJoshi111/Dsbda_codes/blob/main/assign6_DV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import pandas as pd

sns.set_theme( rc={ "figure.figsize": (4,3) } )

# %%
df = pd.read_csv("iris.csv")

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data=df, x="sepal_length", bins=15)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df, x="sepal_width", bins=10)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=df, x="petal_length", bins=10)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=df, x="petal_width", bins=10)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.boxplot(data=df.drop(["species"], axis=1))
# Out:
# <Axes: >

# %%
sns.boxplot(data=df, x="species", y="sepal_length")
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(data=df, x="species", y="sepal_width")
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.boxplot(data=df, x="species", y="petal_length")
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(data=df, x="species", y="petal_width")
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
sns.kdeplot( df , x="sepal_length" )
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>
